# %%
import jax
import jax.numpy as jnp
import jax.random as jr
import matplotlib.pyplot as plt

# %%
key = jr.PRNGKey(4)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
x = jnp.linspace(-10, 10, 100)
def f(key, x): return 2 * jnp.sin(x) + 0.75 * x **2 * jr.normal(key, x.shape) + 0.1 * x ** 2
def f_mean(x): return 2 * jnp.sin(x) + 0.1 * x ** 2


plt.plot(x, f(key, x))
plt.plot(x, f_mean(x))

# %%
@jax.jit
def update(x, learning_rate):
    dx = jax.grad(f_mean)(x)
    x += - learning_rate * dx
    return x


learning_rate = 0.01
max_iter = 10000
x_gd = -10.0
iterates = [x_gd]
for _ in range(max_iter):
    x_gd = update(x_gd, learning_rate)
    iterates.append(x_gd)
iterates = jnp.array(iterates)
plt.plot(iterates)

# %%
plt.figure(figsize=(8, 8))
plt.plot(x,f_mean(x))
plt.plot(iterates, f_mean(iterates), 'rx', markersize = 4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jonathan/uni/thesis/code/nonlinear_model.ipynb Cell 5 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/jonathan/uni/thesis/code/nonlinear_model.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(8, 8))
#       <a href='vscode-notebook-cell:/home/jonathan/uni/thesis/code/nonlinear_model.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> plt.plot(x,f_mean(x))
# ----> <a href='vscode-notebook-cell:/home/jonathan/uni/thesis/code/nonlinear_model.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> plt.plot(iterates, f_mean(iterates), 'rx', markersize = 4)
#
# File /usr/lib/python3.10/site-packages/matplotlib/pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# File /usr/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File /usr/lib/python3.10/site-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File /usr/lib/python3.10/site-packages/matplotlib/axes/_base.py:538, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File /usr/lib/python3.10/site-packages/matplotlib/axes/_base.py:538, in <listcomp>(.0)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File /usr/lib/python3.10/site-packages/matplotlib/axes/_base.py:531, in <genexpr>(.0)
#     528 else:
#     529     labels = [label] * n_datasets
# --> 531 result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                       {**kwargs, 'label': label})
#     533           for j, label in enumerate(labels))
#     535 if return_kwargs:
#     536     return list(result)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:3541, in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#    3538   return _getslice(arr, start, stop)
#    3540 treedef, static_idx, dynamic_idx = _split_index_for_jit(idx, arr.shape)
# -> 3541 return _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    3542                unique_indices, mode, fill_value)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:3550, in _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, fill_value)
#    3547 def _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#    3548             unique_indices, mode, fill_value):
#    3549   idx = _merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# -> 3550   indexer = _index_to_gather(shape(arr), idx)  # shared with _scatter_update
#    3551   y = arr
#    3553   if fill_value is not None:
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:3750, in _index_to_gather(x_shape, idx, normalize_indices)
#    3747 if core.symbolic_equal_dim(x_shape[x_axis], 0):
#    3748   # XLA gives error when indexing into an axis of size 0
#    3749   raise IndexError(f"index is out of bounds for axis {x_axis} with size 0")
# -> 3750 i = _normalize_index(i, x_shape[x_axis]) if normalize_indices else i
#    3751 i = lax.convert_element_type(i, index_dtype)
#    3752 gather_indices.append((i, len(gather_indices_shape)))
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:3424, in _normalize_index(index, axis_size)
#    3420 else:
#    3421   axis_size_val = lax.convert_element_type(core.dimension_as_value(axis_size),
#    3422                                            _dtype(index))
#    3423 return lax.select(
# -> 3424   lax.lt(index, _lax_const(index, 0)),
#    3425   lax.add(index, axis_size_val),
#    3426   index)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/lax.py:468, in lt(x, y)
#     466 def lt(x: Array, y: Array) -> Array:
#     467   r"""Elementwise less-than: :math:`x < y`."""
# --> 468   return lt_p.bind(x, y)
#
# File ~/.local/lib/python3.10/site-packages/jax/core.py:323, in Primitive.bind(self, *args, **params)
#     320 def bind(self, *args, **params):
#     321   assert (not config.jax_enable_checks or
#     322           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 323   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/.local/lib/python3.10/site-packages/jax/core.py:326, in Primitive.bind_with_trace(self, trace, args, params)
#     325 def bind_with_trace(self, trace, args, params):
# --> 326   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     327   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.local/lib/python3.10/site-packages/jax/core.py:675, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     674 def process_primitive(self, primitive, tracers, params):
# --> 675   return primitive.impl(*tracers, **params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/dispatch.py:100, in apply_primitive(prim, *args, **params)
#      97 """Impl rule that compiles and runs a single primitive 'prim' using XLA."""
#      98 compiled_fun = xla_primitive_callable(prim, *unsafe_map(arg_spec, args),
#      99                                       **params)
# --> 100 return compiled_fun(*args)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/dispatch.py:151, in xla_primitive_callable.<locals>.<lambda>(*args, **kw)
#     148 compiled = _xla_callable_uncached(lu.wrap_init(prim_fun), device, None,
#     149                                   prim.name, donated_invars, False, *arg_specs)
#     150 if not prim.multiple_results:
# --> 151   return lambda *args, **kw: compiled(*args, **kw)[0]
#     152 else:
#     153   return compiled
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/dispatch.py:611, in _execute_compiled(name, compiled, input_handler, output_buffer_counts, result_handlers, effects, kept_var_idx, *args)
#     609 device, = compiled.local_devices()
#     610 args = input_handler(args) if input_handler else args
# --> 611 input_bufs_flat = flatten(device_put(x, device) for i, x in enumerate(args)
#     612                           if i in kept_var_idx)
#     613 if effects:
#     614   input_bufs_flat, token_handler = _add_tokens(effects, device, input_bufs_flat)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/util.py:111, in concatenate(xs)
#     109 def concatenate(xs: Iterable[Sequence[T]]) -> List[T]:
#     110   """Concatenates/flattens a list of lists."""
# --> 111   return list(it.chain.from_iterable(xs))
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/dispatch.py:611, in <genexpr>(.0)
#     609 device, = compiled.local_devices()
#     610 args = input_handler(args) if input_handler else args
# --> 611 input_bufs_flat = flatten(device_put(x, device) for i, x in enumerate(args)
#     612                           if i in kept_var_idx)
#     613 if effects:
#     614   input_bufs_flat, token_handler = _add_tokens(effects, device, input_bufs_flat)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/dispatch.py:869, in device_put(x, device)
#     868 def device_put(x, device: Optional[Device] = None) -> Tuple[Any]:
# --> 869   x = xla.canonicalize_dtype(x)
#     870   try:
#     871     return device_put_handlers[type(x)](x, device)
#
# File ~/.local/lib/python3.10/site-packages/jax/interpreters/xla.py:236, in canonicalize_dtype(x)
#     229 xla_shape_handlers[core.AbstractToken] = lambda _: (xc.Shape.token_shape(),)
#     233 # IR constants
#     234
#     235 # TODO(mattjj): try to remove this canonicalize_dtype stuff
# --> 236 def canonicalize_dtype(x):
#     237   typ = type(x)
#     238   handler = canonicalize_dtype_handlers.get(typ)
#
# File _pydevd_bundle/pydevd_cython.pyx:1363, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython.pyx:1664, in _pydevd_bundle.pydevd_cython.ThreadTracer.__call__()
#
# File ~/.local/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_is_thread_alive.py:9, in is_thread_alive(t)
#       6 _temp = threading.Thread()
#       7 if hasattr(_temp, '_is_stopped'):  # Python 3.x has this
# ----> 9     def is_thread_alive(t):
#      10         return not t._is_stopped
#      12 elif hasattr(_temp, '_Thread__stopped'):  # Python 2.x has this
#
# KeyboardInterrupt:

# %%
from functools import partial


@jax.jit
@partial(jax.vmap, in_axes = (0, 0, None))
def sgd_update(key, x, learning_rate):
    dx = jax.grad(f, argnums=(1))(key, x)
    x += - learning_rate * dx
    return x


repetitions = 1000
learning_rate = 0.1
max_iter = 1000
x_gd = -10.0 * jnp.ones((repetitions, ))
iterates = [x_gd]
for _ in range(max_iter):
    keys = jr.split(key, repetitions + 1)
    key = keys[0]
    x_gd = sgd_update(keys[1:], x_gd, learning_rate)
    iterates.append(x_gd)
iterates = jnp.array(iterates)

# %%
keys[0]
keys[1:]
# Out:
# DeviceArray([[2330826875, 3319528305],
#              [1905095750,  300323495],
#              [1636466845, 4294583720],
#              ...,
#              [3663495496, 2549772124],
#              [2921930501, 3493124309],
#              [3814380744,  654980320]], dtype=uint32)

# %%
plt.figure(figsize=(15, 15))
for i in range(repetitions):
    if i % 1 == 100:
        plt.plot(iterates[:,i], alpha = 0.5)

# %%
plt.figure(figsize=(8, 8))
plt.plot(x, f_mean(x))
plt.plot(iterates[:,41], f_mean(iterates[:,41]), 'rx', markersize=4)

# %%
plt.scatter(iterates[-1,:], f_mean(iterates[-1,:]))
